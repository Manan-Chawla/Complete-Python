# %%
import pandas as pd 
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression

# %%
data={
    "payment_mode":["upi","card","cash","card","upi"],
    "amount":[500,800,200,650,300]
}

# %%
df=pd.DataFrame(data)

# %%
df=pd.get_dummies(df,columns=["payment_mode"],drop_first=True)

# %%
print(df)
# Out:
#    amount  payment_mode_cash  payment_mode_upi
# 0     500              False              True
# 1     800              False             False
# 2     200               True             False
# 3     650              False             False
# 4     300              False              True
