# %%
import pandas as pd 
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression

# %%
data={
    "color":["red","blue","green","red","blue"],
    "price":[200,180,220,210,185]
}

# %%
df=pd.DataFrame(data)

# %%
df=pd.get_dummies(df,columns=["color"],drop_first=True)
# when we make it true , it will remove the value which are repeating
# when we make it false, it will not remove the value which are repeating

# %%
print(df)
# Out:
#    price  color_blue  color_green  color_red
# 0    200       False        False       True
# 1    180        True        False      False
# 2    220       False         True      False
# 3    210       False        False       True
# 4    185        True        False      False
