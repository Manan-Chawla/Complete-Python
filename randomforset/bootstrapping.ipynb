# %%
import numpy as np
from sklearn.utils import resample

# %%
data=np.array([10,20,30,40,50])
# simple numeric data
b_sample=resample(data,replace=True,n_samples=5)
print("orginial data : ",data)
print("bootstrapped sample : ",b_sample)
# Out:
# orginial data :  [10 20 30 40 50]
# bootstrapped sample :  [40 10 30 30 20]
