# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
X = [[1], [2], [3], [4], [5], [6]]
y = [0, 0, 0, 1, 1, 1]

boost = AdaBoostClassifier(n_estimators=50)
boost.fit(X, y)

print(boost.predict([[3]]))
# Out:
# [0]
