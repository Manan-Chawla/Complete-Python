# %%
import pandas as pd
from sklearn.utils import resample

# %%
df = pd.DataFrame({
    "salary": [20000, 30000, 40000, 50000, 60000]
})
# bootstrap with df data
boot_df = resample(df, replace=True, n_samples=5)
print(boot_df)
# Out:
#    salary
# 3   50000
# 3   50000
# 1   30000
# 3   50000
# 2   40000
