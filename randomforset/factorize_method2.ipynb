# %%
import pandas as pd 
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression

# %%
data={
    "product":["laptop","phone","tablet","laptop","phone","watch"],
    "price":[60000,25000,30000,89000,34000,12000]
}

# %%
df=pd.DataFrame(data)

# %%
df["product_encoding"],unique_vals=pd.factorize(df["product"])

# %%
print(df)
# Out:
#   product  price  product_encoding
# 0  laptop  60000                 0
# 1   phone  25000                 1
# 2  tablet  30000                 2
# 3  laptop  89000                 0
# 4   phone  34000                 1
# 5   watch  12000                 3

# %%
print("Categories : ",unique_vals)
# Out:
# Categories :  Index(['laptop', 'phone', 'tablet', 'watch'], dtype='object')
