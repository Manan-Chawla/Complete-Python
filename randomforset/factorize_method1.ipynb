# %%
import pandas as pd 
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression

# %%
data={
    "country":["USA","Mexico","Japan","Russia","India"],
    "population":[1400,331,126,1420,120]
}

# %%
df=pd.DataFrame(data)
df["country_encoding_data"],unique_vals=pd.factorize(df["country"])

# %%
print(df)
# Out:
#   country  population  country_encoding_data
# 0     USA        1400                      0
# 1  Mexico         331                      1
# 2   Japan         126                      2
# 3  Russia        1420                      3
# 4   India         120                      4

# %%
print("Cateogries on basis of country : ",unique_vals)
# Out:
# Cateogries on basis of country :  Index(['USA', 'Mexico', 'Japan', 'Russia', 'India'], dtype='object')
