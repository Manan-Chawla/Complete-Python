# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
X=np.array([1,2,3,4,5]).reshape(-1,1)
y=np.array([1,4,9,16,25])

model=LinearRegression()
model.fit(X,y)

print("R2 : ",model.score(X,y)*100)
# Out:
# R2 :  96.25668449197862
